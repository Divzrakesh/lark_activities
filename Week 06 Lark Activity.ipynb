# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the data set into python

# %%
df = pd.read_excel('Dataset_w6.xlsx')

# %%
df
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset

# %%
df['country'].count()
# Out:
# 196

# %% [markdown]
# # 2. Examine the data by using visualizations

# %%
#Barplot of International Trade import Vs Country

plt.figure(figsize=(24,6))
sns.barplot(x='country', y='International trade: Imports (million US$)', data=df.nlargest(10,'International trade: Imports (million US$)'))
plt.title('Barplot of Country Vs International Trade Import',fontsize=25,weight='bold')
plt.xlabel('Country',fontsize=15)
plt.ylabel('International Trade Imports(million US$)',fontsize=15)
plt.grid(linestyle='--')
plt.show()

# %%
# Pair plot
plt.figure(figsize=(10,8))
sns.pairplot(data)
plt.show()

# %%
# Box plot of Region Vs GDP

plt.figure(figsize=(20,20))
sns.boxplot(x='GDP per capita (current US$)',y='Region',data=df)
plt.title('Box plot of Region Vs GDP',fontsize=25,weight='bold')
plt.tight_layout()

# %%
#Northern America has the highest GDP and WesternAfrica has the lowest GDP.

# %%
# Bar plot of Country Vs Population

plt.figure(figsize = (15, 5))
sns.barplot(x=data['country'],y=data['Population in thousands (2017)'],data=data,order=data.sort_values('Population in thousands (2017)',ascending=False).country.head(10))
plt.xlabel("Country",fontsize=15)
plt.ylabel("Population",fontsize=15)
plt.title("Top 10 Countries based on Population",fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3. Find out how many countries with respect to the region are available in the dataset

# %%
df.groupby("Region")[["country"]].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# # 4. On average which region has the highest

# %% [markdown]
# # a. GDP per capita (current US$)

# %%
gdp=df.groupby('Region')[['GDP per capita (current US$)']].mean()
gdp
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                          15135.562500
# CentralAmerica                      6348.137500
# CentralAsia                         4329.880000
# EasternAfrica                       2088.852941
# EasternAsia                        27967.614286
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Micronesia                          5008.300000
# MiddleAfrica                        3928.833333
# NorthernAfrica                      3934.960000
# NorthernAmerica                    57659.000000
# NorthernEurope                     42098.220000
# Oceania                            44823.250000
# Polynesia                           8686.520000
# South-easternAsia                  10299.027273
# SouthAmerica                        8499.775000
# SouthernAfrica                      4191.900000
# SouthernAsia                        2968.400000
# ...

# %%
gdp.nlargest(1,["GDP per capita (current US$)"])
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %%
# Northern America has the highest GDP per capita(current US$)

# %% [markdown]
# # b. International trade: Imports (million US$)

# %%
trade=df.groupby('Region')[['International trade: Imports (million US$)']].mean()
trade
# Out:
#                    International trade: Imports (million US$)
# Region
# Caribbean                                         3057.312500
# CentralAmerica                                   57031.500000
# CentralAsia                                      12063.400000
# EasternAfrica                                     4726.176471
# EasternAsia                                     451995.000000
# EasternEurope                                    85243.900000
# Melanesia                                         2896.400000
# Micronesia                                          99.000000
# MiddleAfrica                                      4381.222222
# NorthernAfrica                                   35034.400000
# NorthernAmerica                                 663552.250000
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# Polynesia                                          432.000000
# ...

# %%
trade.nlargest(1,['International trade: Imports (million US$)'])
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %%
#Northern America has the highest International trade:Imports(million US$)

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
df2=df.groupby('Region')[['GDP per capita (current US$)']].std()
df2.sort_values('GDP per capita (current US$)')
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...

# %%
df2.nsmallest(1,'GDP per capita (current US$)')
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399

# %%
#Western Africa has the lowest standard deviation.Hence more consistent GDP per capita value.
